# %%
import numpy as np
from collections import Counter

# %%
predictions = np.load('results/predicted_labels.npy')
actual = np.load('results/actual_labels.npy')

# %%
Counter(actual)
# Out:
# Counter({3: 3790, 7: 3670, 4: 1240, 1: 500, 2: 410, 5: 230, 6: 160})

# %%
pairs = Counter([(a,b) for a, b in zip(predictions, actual) if a!=b])
pairs
# Out:
# Counter({(7, 3): 2075,
#          (3, 7): 1702,
#          (7, 4): 664,
#          (3, 4): 569,
#          (7, 1): 258,
#          (3, 1): 240,
#          (7, 2): 224,
#          (3, 2): 183,
#          (7, 5): 128,
#          (3, 5): 98,
#          (7, 6): 82,
#          (3, 6): 77,
#          (4, 3): 18,
#          (4, 7): 10,
#          (1, 7): 6,
#          (1, 3): 5,
#          (2, 3): 5,
#          (2, 7): 3,
#          (5, 3): 2,
#          (4, 5): 2,
#          (4, 2): 2,
#          (5, 7): 1,
#          (2, 1): 1,
#          (2, 5): 1,
#          (4, 6): 1,
#          (2, 4): 1})
